# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.heatmap(iris.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [raw]
# The heatmap allows us to visually see the relation between variables in the Iris datset.
#
# - We can observe that petal_length and petal_width have a strong positive correlation.
#
# - We also see that sepal_length and petal_length have strong positive correlation and so do sepal_length and petal_width.
#
# - The rest of the variables have no correlation or weak negative correlation with each other.

# %%
sns.lineplot(x="petal_length", y="petal_width", data = iris, ci = None, color = 'purple')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %% [raw]
# With the line plot, we can observe that usually as petals get longer, they also get wider.

# %%
fig=plt.figure(figsize = (15,15))
ax = fig.add_subplot(2,1,1)
sns.scatterplot(x="sepal_length", y="petal_length", data = iris,color = 'orange')
ax1 = fig.add_subplot(2,1,2)
sns.scatterplot(x="sepal_length", y="petal_width", data = iris,color = 'magenta')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %% [raw]
# We can observe that the longer the petal is or the wider a petal is, the length of the sepal is also most likey to be longer.

# %%
sns.countplot(x="species", data = iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %% [raw]
# We observe that there are three flower species used in this dataset, which are
#     -setosa
#     -versicolor
#     -virginica
#
# We can also decipher through this visualization that each species has almost the same number of records in the data set.

# %%
fig=plt.figure(figsize = (10,15))
ax1 = fig.add_subplot(4,1,1)
sns.distplot(iris["petal_length"], color = 'purple')

ax2 = fig.add_subplot(4,1,2)
sns.distplot(iris["petal_width"], color = 'pink')

ax3 = fig.add_subplot(4,1,3)
sns.distplot(iris["sepal_length"], color = 'magenta')

ax4 = fig.add_subplot(4,1,4)
sns.distplot(iris["sepal_width"], color = 'red')
# Out:
# C:\Users\Safiya\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Safiya\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [raw]
# This figure helps us understand the most common dimensions of the petals and sepals.
#
#     - Most of the lengths of the petal lies either between 1 and 2 or 4 and 6.
#     - Most of the widths of the petal lies either between 0 and 0.5 or 1 and 2.
#     - The sepal length lies mostly in between 5 and 7.
#     - The sepal width lies mostly in between 2.5 and 3.5.
